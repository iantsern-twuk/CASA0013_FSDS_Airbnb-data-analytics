# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url_listings_2024  = f'/Users/tsernian/Documents/CASA/CASA0013_FSDS/CASA0013_FSDS_Airbnb_living la vida code-a/Documentation/data/listings.csv.gz'
url_listings_2021 = f'/Users/tsernian/Documents/CASA/CASA0013_FSDS/CASA0013_FSDS_Airbnb_living la vida code-a/Documentation/data/2021_listings.csv.gz'
url_listings_2022 = f'/Users/tsernian/Documents/CASA/CASA0013_FSDS/CASA0013_FSDS_Airbnb_living la vida code-a/Documentation/data/2022_listings.csv.gz'
url_listings_2023 = f'/Users/tsernian/Documents/CASA/CASA0013_FSDS/CASA0013_FSDS_Airbnb_living la vida code-a/Documentation/data/2023_listings.csv.gz'

# %%
df_listings_2024 = pd.read_csv(url_listings_2024, compression='gzip', low_memory=False) #compression='gzip' is to unzip the file
df_listings_2021 = pd.read_csv(url_listings_2021, compression='gzip', low_memory=False)
df_listings_2022 = pd.read_csv(url_listings_2022, compression='gzip', low_memory=False)
df_listings_2023 = pd.read_csv(url_listings_2023, compression='gzip', low_memory=False)

print(f"Data frame listings_2024 is {df_listings_2024.shape[0]:,} x {df_listings_2024.shape[1]}")
print(f"Data frame listings_2021 is {df_listings_2021.shape[0]:,} x {df_listings_2021.shape[1]}")
print(f"Data frame listings_2022 is {df_listings_2022.shape[0]:,} x {df_listings_2022.shape[1]}")
print(f"Data frame listings_2023 is {df_listings_2023.shape[0]:,} x {df_listings_2023.shape[1]}")
# Out:
# Data frame listings_2024 is 96,182 x 75
# Data frame listings_2021 is 70,617 x 74
# Data frame listings_2022 is 69,351 x 75
# Data frame listings_2023 is 87,946 x 75

# %%
df_listings_2024.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96182 entries, 0 to 96181
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            96182 non-null  int64
#  1   listing_url                                   96182 non-null  object
#  2   scrape_id                                     96182 non-null  int64
#  3   last_scraped                                  96182 non-null  object
#  4   source                                        96182 non-null  object
#  5   name                                          96182 non-null  object
#  6   description                                   92763 non-null  object
#  7   neighborhood_overview                         45661 non-null  object
#  8   picture_url                                   96171 non-null  object
#  9   host_id                                       96182 non-null  int64
#  10  host_url                                      96182 non-null  object
#  11  host_name                                     96177 non-null  object
#  12  host_since                                    96177 non-null  object
#  13  host_location                                 73913 non-null  object
#  14  host_about                                    49035 non-null  object
#  15  host_response_time                            64301 non-null  object
#  16  host_response_rate                            64301 non-null  object
#  17  host_acceptance_rate                          68956 non-null  object
#  18  host_is_superhost                             94694 non-null  object
#  19  host_thumbnail_url                            96177 non-null  object
#  20  host_picture_url                              96177 non-null  object
#  21  host_neighbourhood                            47625 non-null  object
#  22  host_listings_count                           96177 non-null  float64
#  23  host_total_listings_count                     96177 non-null  float64
#  24  host_verifications                            96177 non-null  object
#  25  host_has_profile_pic                          96177 non-null  object
#  26  host_identity_verified                        96177 non-null  object
#  27  neighbourhood                                 45662 non-null  object
#  28  neighbourhood_cleansed                        96182 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      96182 non-null  float64
#  31  longitude                                     96182 non-null  float64
#  32  property_type                                 96182 non-null  object
#  33  room_type                                     96182 non-null  object
#  34  accommodates                                  96182 non-null  int64
#  35  bathrooms                                     63145 non-null  float64
#  36  bathrooms_text                                96026 non-null  object
#  37  bedrooms                                      83530 non-null  float64
#  38  beds                                          63041 non-null  float64
#  39  amenities                                     96182 non-null  object
#  40  price                                         63205 non-null  object
#  41  minimum_nights                                96182 non-null  int64
#  42  maximum_nights                                96182 non-null  int64
#  43  minimum_minimum_nights                        96181 non-null  float64
#  44  maximum_minimum_nights                        96181 non-null  float64
#  45  minimum_maximum_nights                        96181 non-null  float64
#  46  maximum_maximum_nights                        96181 non-null  float64
#  47  minimum_nights_avg_ntm                        96181 non-null  float64
#  48  maximum_nights_avg_ntm                        96181 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              91921 non-null  object
#  51  availability_30                               96182 non-null  int64
#  52  availability_60                               96182 non-null  int64
#  53  availability_90                               96182 non-null  int64
#  54  availability_365                              96182 non-null  int64
#  55  calendar_last_scraped                         96182 non-null  object
#  56  number_of_reviews                             96182 non-null  int64
#  57  number_of_reviews_ltm                         96182 non-null  int64
#  58  number_of_reviews_l30d                        96182 non-null  int64
#  59  first_review                                  71649 non-null  object
#  60  last_review                                   71649 non-null  object
#  61  review_scores_rating                          71649 non-null  float64
#  62  review_scores_accuracy                        71631 non-null  float64
#  63  review_scores_cleanliness                     71639 non-null  float64
#  64  review_scores_checkin                         71599 non-null  float64
#  65  review_scores_communication                   71625 non-null  float64
#  66  review_scores_location                        71598 non-null  float64
#  67  review_scores_value                           71599 non-null  float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              96182 non-null  object
#  70  calculated_host_listings_count                96182 non-null  int64
#  71  calculated_host_listings_count_entire_homes   96182 non-null  int64
#  72  calculated_host_listings_count_private_rooms  96182 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   96182 non-null  int64
#  74  reviews_per_month                             71649 non-null  float64
# dtypes: float64(24), int64(17), object(34)
# memory usage: 55.0+ MB

# %%
columns_2024 = set(df_listings_2024.columns)
columns_2021 = set(df_listings_2021.columns)
columns_2022 = set(df_listings_2022.columns)
columns_2023 = set(df_listings_2023.columns)


diff_2024_2021 = columns_2024.symmetric_difference(columns_2021)
diff_2024_2022 = columns_2024.symmetric_difference(columns_2022)
diff_2024_2023 = columns_2024.symmetric_difference(columns_2023)

print("Columns different between 2024 and 2021:", diff_2024_2021)
print("Columns different between 2024 and 2022:", diff_2024_2022)
print("Columns different between 2024 and 2023:", diff_2024_2023)
# Out:
# Columns different between 2024 and 2021: {'source'}
# Columns different between 2024 and 2022: set()
# Columns different between 2024 and 2023: set()

# %%
#add a new column called year to each dataframe
df_listings_2024['year'] = 2024
df_listings_2021['year'] = 2021
df_listings_2022['year'] = 2022
df_listings_2023['year'] = 2023

df_listings_combined = pd.concat([df_listings_2024, df_listings_2021, df_listings_2022, df_listings_2023], axis=0, ignore_index=True)   
print(f"Combined data frame is {df_listings_combined.shape[0]:,} x {df_listings_combined.shape[1]}")

#select the column I want to use
columns_to_use = ['id', 'listing_url', 'name', 'host_id', 'host_name', 'host_listings_count', 'host_total_listings_count', 'latitude', 'longitude', 'property_type', 'room_type', 'price', 'number_of_reviews','review_scores_rating', 'year']
df_listings_combined = df_listings_combined[columns_to_use]
print(f"Combined data frame is {df_listings_combined.shape[0]:,} x {df_listings_combined.shape[1]}")
# Out:
# Combined data frame is 324,096 x 76
# Combined data frame is 324,096 x 15

# %%
df_listings_combined
# Out:
#                         id                                      listing_url  \
# 0                    13913               https://www.airbnb.com/rooms/13913
# 1                    15400               https://www.airbnb.com/rooms/15400
# 2                    17402               https://www.airbnb.com/rooms/17402
# 3                    24328               https://www.airbnb.com/rooms/24328
# 4                    33332               https://www.airbnb.com/rooms/33332
# ...                    ...                                              ...
# 324091  973781286754517228  https://www.airbnb.com/rooms/973781286754517228
# 324092  973801695874775338  https://www.airbnb.com/rooms/973801695874775338
# 324093  973811685656289740  https://www.airbnb.com/rooms/973811685656289740
# 324094  973882998775927897  https://www.airbnb.com/rooms/973882998775927897
# 324095  973895808066047620  https://www.airbnb.com/rooms/973895808066047620
#
#                                                      name    host_id  \
# 0                     Holiday London DB Room Let-on going      54730
# 1                     Bright Chelsea  Apartment. Chelsea!      60302
# 2                      Fab 3-Bed/2 Bath & Wifi: Trendy W1      67564
# 3       Battersea live/work artist house, garden & par...      41759
# 4          Beautiful Ensuite Richmond-upon-Thames borough     144444
# ...                                                   ...        ...
# 324091  Rental unit in Greater London · ★New · 1 bedro...  498408783
# 324092  Rental unit in Greater London · ★New · 1 bedro...   36645347
# 324093  Home in Greater London · ★New · 1 bedroom · 5 ...  340514057
# 324094  Home in Greater London · ★New · 5 bedrooms · 5...  439074505
# 324095  Rental unit in Greater London · ★New · 2 bedro...  475112423
#
#          host_name  host_listings_count  host_total_listings_count   latitude  \
# 0            Alina                  3.0                        4.0  51.568610
# 1         Philippa                  1.0                        1.0  51.487800
# 2              Liz                  7.0                       32.0  51.521950
# 3              Joe                  1.0                        3.0  51.470720
# 4          Chi-Chi                  2.0                        2.0  51.464100
# ...            ...                  ...                        ...        ...
# 324091         Sal                  2.0                        2.0  51.514860
# 324092       Josie                  1.0                        1.0  51.459042
# 324093         Mal                  1.0                        1.0  51.406100
# 324094  Travelnest               2538.0                     5217.0  51.450997
# 324095         Lea                 37.0                       47.0  51.515970
#
#         longitude                property_type        room_type    price  \
# 0       -0.112700  Private room in rental unit     Private room   $59.00
# 1       -0.168130           Entire rental unit  Entire home/apt  $120.00
# 2       -0.140940           Entire rental unit  Entire home/apt  $493.00
# 3       -0.162660             Entire townhouse  Entire home/apt  $190.00
# 4       -0.324980         Private room in home     Private room  $140.00
# ...           ...                          ...              ...      ...
# 324091  -0.135980           Entire rental unit  Entire home/apt  $275.00
# 324092  -0.055458           Entire rental unit  Entire home/apt  $145.00
# 324093  -0.236126         Private room in home     Private room  $160.00
# 324094  -0.444319                  Entire home  Entire home/apt  $680.00
# 324095  -0.111342           Entire rental unit  Entire home/apt  $170.00
#
#         number_of_reviews  review_scores_rating  year
# 0                      44                  4.82  2024
# 1                      96                  4.80  2024
# 2                      56                  4.77  2024
# 3                      94                  4.90  2024
# 4                      19                  4.37  2024
# ...                   ...                   ...   ...
# 324091                  0                   NaN  2023
# 324092                  0                   NaN  2023
# 324093                  0                   NaN  2023
# 324094                  0                   NaN  2023
# 324095                  0                   NaN  2023
#
# [324096 rows x 15 columns]

# %%
#how many unigue id and host id
print(f"Number of unique id is {df_listings_combined['id'].nunique():,}")
print(f"Number of unique host id is {df_listings_combined['host_id'].nunique():,}")
# Out:
# Number of unique id is 161,361
# Number of unique host id is 85,219

# %%
#select by host id annd year range
host_id = 54730
start_year = 2023
end_year = 2024

def select_function(df, host_id, start_year, end_year):
    return df[(df['host_id'] == host_id) & (df['year'] >= start_year) & (df['year'] <= end_year)]

df_listings_combined_by_host_id_and_year_range = select_function(df_listings_combined, host_id, start_year, end_year)
df_listings_combined_by_host_id_and_year_range
# Out:
#                          id                                       listing_url  \
# 0                     13913                https://www.airbnb.com/rooms/13913
# 117                   89870                https://www.airbnb.com/rooms/89870
# 70989   1021187456703584211  https://www.airbnb.com/rooms/1021187456703584211
# 236152                13913                https://www.airbnb.com/rooms/13913
# 236273                89870                https://www.airbnb.com/rooms/89870
#
#                                                      name  host_id host_name  \
# 0                     Holiday London DB Room Let-on going    54730     Alina
# 117                     London Holiday Flat Let-Islington    54730     Alina
# 70989                    Lovely Art Flat in Finsbury Park    54730     Alina
# 236152  Rental unit in Islington · ★4.80 · 1 bedroom ·...    54730     Alina
# 236273  Rental unit in London · ★4.63 · 1 bedroom · 1 ...    54730     Alina
#
#         host_listings_count  host_total_listings_count   latitude  longitude  \
# 0                       3.0                        4.0  51.568610  -0.112700
# 117                     3.0                        4.0  51.567920  -0.111250
# 70989                   3.0                        4.0  51.570208  -0.113028
# 236152                  3.0                        4.0  51.568610  -0.112700
# 236273                  3.0                        4.0  51.567920  -0.111250
#
#                       property_type        room_type    price  \
# 0       Private room in rental unit     Private room   $59.00
# 117              Entire rental unit  Entire home/apt  $143.00
# 70989            Entire rental unit  Entire home/apt  $143.00
# 236152  Private room in rental unit     Private room   $79.00
# 236273           Entire rental unit  Entire home/apt  $149.00
#
#         number_of_reviews  review_scores_rating  year
# 0                      44                  4.82  2024
# 117                   142                  4.63  2024
# 70989                   1                  5.00  2024
# 236152                 41                  4.80  2023
# 236273                129                  4.63  2023

# %% [markdown]
# ### I don't know why host_listings_count and host_total_listings_count are different and It should count in 2 in 2023 so I will drop them and count it again

# %%
df_host_listings_count = df_listings_combined.groupby(['host_id', 'year'])['id'].nunique().reset_index()
df_host_listings_count.columns = ['host_id', 'year', 'host_listings_count']
df_host_listings_count

filtered_df = df_host_listings_count[df_host_listings_count['host_id'] == 54730]
print(filtered_df)
# Out:
#      host_id  year  host_listings_count
# 146    54730  2021                    2
# 147    54730  2022                    2
# 148    54730  2023                    2
# 149    54730  2024                    3

# %%
df_host_listings_count_fliter = df_host_listings_count [df_host_listings_count['year'] <= 2024]    
statistics_summary = df_host_listings_count_fliter['host_listings_count'].describe()
print(statistics_summary)
# Out:
# count    202381.000000
# mean          1.601415
# std           5.311590
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max         864.000000
# Name: host_listings_count, dtype: float64

# %%
bins = [0, 2, float('inf')] #catogrize host_listings_count into <=1 and >2
labels = ['Single Property hosts', 'Multiple Properties hosts']
df_host_listings_count['category'] = pd.cut(df_host_listings_count['host_listings_count'], bins=bins, labels=labels, right=False)

sns.set(style="whitegrid") #like darkgrid, whitegrid, dark, white, ticks
plt.figure(figsize=(10, 8))


for i, year in enumerate(range(2021, 2025), 1): # i is the index of the year
    plt.subplot(2, 2, i) 
    yearly_data = df_host_listings_count[df_host_listings_count['year'] == year]
    category_counts = yearly_data['category'].value_counts().sort_index()
    plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)  #startangle=140 is to rotate the pie chart #autopct is to show the percentage
    plt.title(f'Host ID Distribution in {year}')


plt.tight_layout()
plt.show()

# %%
df_host_listings_count
# Out:
#           host_id  year  host_listings_count             category
# 0            2010  2021                    1     Single Property
# 1            2594  2024                    1     Single Property
# 2            4775  2021                    7  Multiple Properties
# 3            4775  2022                    7  Multiple Properties
# 4            4775  2023                    6  Multiple Properties
# ...           ...   ...                  ...                  ...
# 202376  650145538  2024                    1     Single Property
# 202377  650159011  2024                    1     Single Property
# 202378  650171076  2024                    1     Single Property
# 202379  650251399  2024                    2  Multiple Properties
# 202380  650265895  2024                    1     Single Property
#
# [202381 rows x 4 columns]

# %%
df_new_listings_combined = df_listings_combined.merge(df_host_listings_count, on=['host_id', 'year'], how='left') 
df_new_listings_combined = df_new_listings_combined.rename(columns={'host_listings_count_y': 'new_host_listings_count'})
df_new_listings_combined

#df_new_listings_combined.to_csv('df_new_listings_combined.csv', index=False)
# Out:
#                         id                                      listing_url  \
# 0                    13913               https://www.airbnb.com/rooms/13913
# 1                    15400               https://www.airbnb.com/rooms/15400
# 2                    17402               https://www.airbnb.com/rooms/17402
# 3                    24328               https://www.airbnb.com/rooms/24328
# 4                    33332               https://www.airbnb.com/rooms/33332
# ...                    ...                                              ...
# 324091  973781286754517228  https://www.airbnb.com/rooms/973781286754517228
# 324092  973801695874775338  https://www.airbnb.com/rooms/973801695874775338
# 324093  973811685656289740  https://www.airbnb.com/rooms/973811685656289740
# 324094  973882998775927897  https://www.airbnb.com/rooms/973882998775927897
# 324095  973895808066047620  https://www.airbnb.com/rooms/973895808066047620
#
#                                                      name    host_id  \
# 0                     Holiday London DB Room Let-on going      54730
# 1                     Bright Chelsea  Apartment. Chelsea!      60302
# 2                      Fab 3-Bed/2 Bath & Wifi: Trendy W1      67564
# 3       Battersea live/work artist house, garden & par...      41759
# 4          Beautiful Ensuite Richmond-upon-Thames borough     144444
# ...                                                   ...        ...
# 324091  Rental unit in Greater London · ★New · 1 bedro...  498408783
# 324092  Rental unit in Greater London · ★New · 1 bedro...   36645347
# 324093  Home in Greater London · ★New · 1 bedroom · 5 ...  340514057
# 324094  Home in Greater London · ★New · 5 bedrooms · 5...  439074505
# 324095  Rental unit in Greater London · ★New · 2 bedro...  475112423
#
#          host_name  host_listings_count_x  host_total_listings_count  \
# 0            Alina                    3.0                        4.0
# 1         Philippa                    1.0                        1.0
# 2              Liz                    7.0                       32.0
# 3              Joe                    1.0                        3.0
# 4          Chi-Chi                    2.0                        2.0
# ...            ...                    ...                        ...
# 324091         Sal                    2.0                        2.0
# 324092       Josie                    1.0                        1.0
# 324093         Mal                    1.0                        1.0
# 324094  Travelnest                 2538.0                     5217.0
# 324095         Lea                   37.0                       47.0
#
#          latitude  longitude                property_type        room_type  \
# 0       51.568610  -0.112700  Private room in rental unit     Private room
# 1       51.487800  -0.168130           Entire rental unit  Entire home/apt
# 2       51.521950  -0.140940           Entire rental unit  Entire home/apt
# 3       51.470720  -0.162660             Entire townhouse  Entire home/apt
# 4       51.464100  -0.324980         Private room in home     Private room
# ...           ...        ...                          ...              ...
# 324091  51.514860  -0.135980           Entire rental unit  Entire home/apt
# 324092  51.459042  -0.055458           Entire rental unit  Entire home/apt
# 324093  51.406100  -0.236126         Private room in home     Private room
# 324094  51.450997  -0.444319                  Entire home  Entire home/apt
# 324095  51.515970  -0.111342           Entire rental unit  Entire home/apt
#
#           price  number_of_reviews  review_scores_rating  year  \
# 0        $59.00                 44                  4.82  2024
# 1       $120.00                 96                  4.80  2024
# 2       $493.00                 56                  4.77  2024
# 3       $190.00                 94                  4.90  2024
# 4       $140.00                 19                  4.37  2024
# ...         ...                ...                   ...   ...
# 324091  $275.00                  0                   NaN  2023
# 324092  $145.00                  0                   NaN  2023
# 324093  $160.00                  0                   NaN  2023
# 324094  $680.00                  0                   NaN  2023
# 324095  $170.00                  0                   NaN  2023
#
#         new_host_listings_count                   category
# 0                             3  Multiple Properties hosts
# 1                             1      Single Property hosts
# 2                             6  Multiple Properties hosts
# 3                             1      Single Property hosts
# 4                             2  Multiple Properties hosts
# ...                         ...                        ...
# 324091                        2  Multiple Properties hosts
# 324092                        1      Single Property hosts
# 324093                        1      Single Property hosts
# 324094                      170  Multiple Properties hosts
# 324095                        6  Multiple Properties hosts
#
# [324096 rows x 17 columns]

# %%
labels = ['The listings of single Property hosts', 'The listings of Multiple Properties hosts']

sns.set(style="whitegrid") #like darkgrid, whitegrid, dark, white, ticks
plt.figure(figsize=(12, 4))

patches = []

for i, year in enumerate(range(2021, 2025), 1): # i is the index of the year
    ax =  plt.subplot(1, 4, i) 
    ax.set_aspect('equal')
   
    yearly_data = df_new_listings_combined[df_new_listings_combined['year'] == year]
    category_counts = yearly_data['category'].value_counts().sort_index()  # yearly_data category_counts
    wedges, texts, autotexts = plt.pie(category_counts, labels=None, autopct='%1.1f%%', startangle=140)  # no labels
    plt.title(f'{year}', fontsize=14)
    
    # add legend only in the first loop
    if i == 1:
        patches = wedges

# label legend
plt.legend(patches, labels, loc='lower left', bbox_to_anchor=(0.1, -0.2))    #loc choose have lower left, lower right, upper left, upper right  

plt.tight_layout()
plt.show()

# %%
#check data by year 
count_id_by_year = df_new_listings_combined.groupby(['year']).count()
print(count_id_by_year['id'])
# Out:
# year
# 2021    70617
# 2022    69351
# 2023    87946
# 2024    96182
# Name: id, dtype: int64

# %%
multiple_properties_ids = df_new_listings_combined[df_new_listings_combined['category'] == 'Multiple Properties hosts'].groupby('year')['id'].nunique()
single_property_ids = df_new_listings_combined[df_new_listings_combined['category'] == 'Single Property hosts'].groupby('year')['id'].nunique()
percentage_multiple_properties_ids = multiple_properties_ids / (multiple_properties_ids + single_property_ids)

sns.set(style="white") #like darkgrid, whitegrid, dark, white, ticks
fig, ax1 = plt.subplots(figsize=(10, 6))
bar_width = 0.35

index = np.arange(len(multiple_properties_ids))

# bar chart
ax1.bar(multiple_properties_ids.index, multiple_properties_ids,width=bar_width, color='#DD8452', label='listings of multiple properties')
ax1.bar(single_property_ids.index + bar_width, single_property_ids,width=bar_width, color='#4C72B0', label='listings of single property')
ax1.set_xlabel('Year')
ax1.set_ylabel('count of listings', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_xticks(multiple_properties_ids.index)  # year scale

# secondary y axis line chart
ax2 = ax1.twinx()
ax2.plot(percentage_multiple_properties_ids.index, percentage_multiple_properties_ids, color='#212121', marker='o',linestyle='--', linewidth=2, label='Percentage of Multiple Properties')
ax2.set_ylabel('Host ID Percentage (%)', color='black')
ax2.tick_params(axis='y', labelcolor='black')


# add legend
fig.legend(loc='upper left', bbox_to_anchor=(0.13, 0.88))
plt.grid(color='gray', linestyle='--', linewidth=0.5)

plt.title('Percentage of Multiple Properties by Year')
plt.grid(True)
plt.show()

# %%
#for pie chart
multiple_properties_host_ids = df_new_listings_combined[df_new_listings_combined['category'] == 'Multiple Properties hosts'].groupby('year')['host_id'].nunique()
single_property_host_ids = df_new_listings_combined[df_new_listings_combined['category'] == 'Single Property hosts'].groupby('year')['host_id'].nunique()
percentage_multiple_properties_host_ids = multiple_properties_host_ids / (multiple_properties_host_ids + single_property_host_ids)

# for line chart and bar chart
multiple_properties_ids = df_new_listings_combined[df_new_listings_combined['category'] == 'Multiple Properties hosts'].groupby('year')['id'].nunique()
single_property_ids = df_new_listings_combined[df_new_listings_combined['category'] == 'Single Property hosts'].groupby('year')['id'].nunique()
percentage_multiple_properties_ids = multiple_properties_ids / (multiple_properties_ids + single_property_ids)

labels = ['The listings of single Property hosts', 'The listings of Multiple Properties hosts']

sns.set(style="white")
fig = plt.figure(figsize=(20, 10))
gs = fig.add_gridspec(2, 4)  # 2 rows, 4 columns

# pie chart
patches = []
for i, year in enumerate(range(2021, 2025), 1):
    ax = fig.add_subplot(gs[0, i-1])  #i-1 is to start from 0
    ax.set_aspect('equal')
   
    yearly_data = df_new_listings_combined[df_new_listings_combined['year'] == year]
    wedges, texts, autotexts = ax.pie(category_counts, labels=None, autopct='%1.1f%%', startangle=140)
    ax.set_title(f'{year}', fontsize=14, fontweight='normal', loc='center', y=0.95) #loc have center, left, right, upper, lower
    
    if i == 1:
        patches = wedges

# legend of pie chart
fig.legend(patches, labels, loc='upper left', bbox_to_anchor=(0.05, 1.))

# line chart and bar chart
ax1 = fig.add_subplot(gs[1, :]) 
bar_width = 0.18
index = np.arange(len(multiple_properties_ids))

# bar chart
ax1.bar(index, multiple_properties_ids, width=bar_width, color='#DD8452', label='listings of multiple properties')
ax1.bar(index + bar_width, single_property_ids, width=bar_width, color='#4C72B0', label='listings of single property')
ax1.set_xlabel('Year')
ax1.set_ylabel('count of listings', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_xticks(index + bar_width / 2)
ax1.set_xticklabels(multiple_properties_ids.index)

# line chart
ax2 = ax1.twinx()
ax2.plot(index + bar_width / 2, percentage_multiple_properties_ids, color='#212121', marker='o', linestyle='--', linewidth=2, label='Percentage of Multiple Properties')
ax2.set_ylabel('Host ID Percentage (%)', color='black')
ax2.tick_params(axis='y', labelcolor='black')

# legend of line chart and bar chart
fig.legend(loc='upper left', bbox_to_anchor=(0.05, 0.48))
plt.grid(color='gray', linestyle='--', linewidth=0.5)

plt.suptitle('', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96]) 
plt.show()

# %%
print(category_counts)
multiple_properties_host_ids = df_new_listings_combined[df_new_listings_combined['category'] == 'Multiple Properties hosts'].groupby('year')['host_id'].nunique()
single_property_host_ids = df_new_listings_combined[df_new_listings_combined['category'] == 'Single Property hosts'].groupby('year')['host_id'].nunique()
percentage_multiple_properties_host_ids = multiple_properties_host_ids / (multiple_properties_host_ids + single_property_host_ids)

print)(percentage_multiple_properties_host_ids)
# Out:
# category
# Single Property hosts        45937
# Multiple Properties hosts    50245
# Name: count, dtype: int64
